# %%
from openai import OpenAI
import voyageai as vo  
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client_vo = vo.Client(api_key=os.getenv("VOYAGE_API_KEY"))  
chat_model = "gpt-3.5-turbo"
embedding_model = "voyage-context-3"

# %%
k = 3
a = 0.6 #alpha for semantic (1.0) and keyword search (0.0)
lambda_parameter = 0.7 #lambda for diversity (1.0 is all diverse) and 0.0 is chunks are the same

# %%
import os
from ingestion import load_documents
base_path = os.path.abspath("..")
md_texts = load_documents(base_path)

# %%
from sentence_transformers import SentenceTransformer
import re

model = SentenceTransformer("all-MiniLM-L6-v2") #"all-mpnet-base-v2"

all_text = "\n".join(doc["text"] for doc in md_texts)

paragraphs = re.split(r'\n\s*\n+', all_text)
paragraphs = [p.strip() for p in paragraphs if len(p.strip()) > 100]

# %%
print(len(paragraphs), "total chunks created")
print(paragraphs[1])
# Out:
# 352 total chunks created
# Define reproductive health in the workplace: not just fertility, but encompassing menstrual health, menopause, and other reproductive challenges.

# %%
import numpy as np

chunk_texts = [c for c in paragraphs]

resp = client_vo.contextualized_embed(
    inputs=[[text] for text in chunk_texts],
    model=embedding_model,      # e.g. "voyage-context-3"
    input_type="document"
)

chunk_embeddings = np.array(
    [r.embeddings[0] for r in resp.results],
    dtype=np.float32
)

chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

# %%
from rag import response_llm, embed_query
import json

with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)
questions = [q["question"] for q in qa_data]

# Run
llm_results = response_llm(
    questions=questions,
    client=client,
    chat_model=chat_model,
    chunk_embeddings=chunk_embeddings,
    chunk_texts=chunk_texts,
    embed_query=embed_query,
    k=k,
    alpha=a,
    lambda_param=lambda_parameter
)
# Out:
# Q1: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Introduction:
#
# For organizations looking to create a workplace environment that supports reproductive and fertility health for all employees, it is essential to develop and implement inclusive policies that cater to the diverse needs and beliefs of their workforce. By following best practices in this area, organizations can create a supportive and inclusive environment where employees feel valued and cared for throughout their reproductive health journey.
#
# Best Practices for Developing and Implementing Reproductive and Fertility Health Policies:
#
# 1. Cultural Sensitivity and Religious Inclusivity:
# One of the first steps in developing reproductive and fertility health policies is to ensure cultural sensitivity and religious inclusivity. Organizations should adapt policies based on regional attitudes towards reproductive healthcare and offer flexible benefits that align with diverse religious beliefs. This approach helps create a supportive environment where employees feel respected and understood, regardless of their cultural or religious background.
#
# 2. Education and Awareness:
# Providing education and awareness programs is crucial to normalizing discussions around reproductive and fertility health in the workplace. Workshops, training sessions, and peer support groups can help educate employees about various reproductive health issues and promote open communication on these topics. By raising awareness and breaking down stigma, organizations can create a more supportive and inclusive environment for all employees.
#
# 3. Access and Affordability:
# Partnering with healthcare providers and NGOs to expand access to reproductive and fertility health services is another important aspect of developing inclusive policies. By collaborating with external organizations, employers can ensure that their employees have access to necessary resources and support, especially in resource-limited areas. This proactive approach demonstrates a commitment to supporting employees' reproductive health needs, regardless of their financial or geographical constraints.
#
# 4. Legal Compliance:
# Ensuring that reproductive and fertility health policies align with local labor laws and healthcare regulations is essential for organizations to avoid legal issues and protect the rights of their employees. By staying up-to-date with relevant regulations and guidelines, employers can create policies that are both supportive and compliant, fostering a safe and inclusive workplace environment for all employees.
#
# 5. Flexible Work and Leave Policies:
# Addressing time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns is crucial for supporting employees' well-being and productivity. By offering flexible work arrangements and leave policies that accommodate employees' reproductive health needs, organizations can demonstrate their commitment to inclusivity and support. This approach helps employees feel valued and supported during critical moments in their reproductive health journey.
#
# Conclusion:
#
# In conclusion, developing and implementing reproductive and fertility health policies in the workplace requires a holistic approach that considers cultural sensitivity, religious inclusivity, education, access, affordability, legal compliance, and flexibility. By following best practices in these areas, organizations can create a supportive and inclusive environment where all employees feel valued and cared for throughout their reproductive health journey. By prioritizing inclusivity and support, employers can promote employee well-being, productivity, and overall organizational success.
#
# Q2: Write a 500 word report on what are the best practices for developing and applying reproductive and fertility health policies in the workplace to ensure inclusivity and support for employees?
# Answer: Introduction:
# Reproductive and fertility health policies in the workplace are crucial for supporting employees' diverse needs and ensuring inclusivity. By developing and applying best practices in this area, employers can create a supportive environment that respects employees' choices, beliefs, and health concerns. In this report, we will explore the key components of effective reproductive and fertility health policies in the workplace.
#
# Cultural Sensitivity:
# One of the best practices for developing inclusive reproductive and fertility health policies is to adapt them based on regional attitudes toward reproductive healthcare. Employers should be aware of cultural differences and tailor their policies to respect and accommodate various beliefs and practices related to fertility, pregnancy, and reproductive health. By being culturally sensitive, employers can ensure that their policies are inclusive and respectful of employees from diverse backgrounds.
#
# Religious Inclusivity:
# Another important aspect of developing reproductive health policies is to offer flexible benefits that align with diverse religious beliefs. Employers should take into consideration the religious beliefs of their employees when designing policies related to fertility treatments, pregnancy loss, and other reproductive health issues. By offering benefits that respect and accommodate diverse religious beliefs, employers can create a supportive environment that values employees' perspectives and choices.
#
# Education & Awareness:
# Providing education, workshops, training, and peer support on reproductive and fertility health is another best practice for developing inclusive policies in the workplace. By normalizing discussions around reproductive health issues, employers can create a more open and supportive environment for employees to seek help, information, and resources. By investing in education and awareness initiatives, employers can empower employees to make informed decisions about their reproductive health and seek support when needed.
#
# Access & Affordability:
# Partnering with healthcare providers and NGOs to expand access to reproductive and fertility health services in resource-limited areas is essential for developing inclusive policies. By ensuring that employees have access to affordable and quality healthcare services, employers can support employees in managing their reproductive health needs. By collaborating with external partners, employers can leverage resources and expertise to expand access to reproductive health services for all employees, regardless of their location or financial status.
#
# Legal Compliance:
# Ensuring that reproductive health policies align with local labor laws and healthcare regulations is a fundamental best practice for developing inclusive policies. Employers must stay informed about legal requirements related to reproductive and fertility health in the workplace and ensure that their policies comply with these regulations. By prioritizing legal compliance, employers can create a safe and supportive environment for employees to address their reproductive health needs without fear of discrimination or legal issues.
#
# Flexible Work and Leave Policies:
# Addressing time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns is crucial for supporting employees' well-being and work-life balance. By offering flexible work and leave policies that accommodate employees' reproductive health needs, employers can demonstrate their commitment to supporting employees' physical and emotional well-being. By providing options for flexible scheduling, remote work, and extended leave, employers can help employees manage their reproductive health needs without compromising their career or financial stability.
#
# Conclusion:
# In conclusion, developing and applying best practices for reproductive and fertility health policies in the workplace is essential for ensuring inclusivity and support for employees. By being culturally sensitive, religiously inclusive, educationally aware, accessible, legally compliant, and offering flexible work and leave policies, employers can create a supportive environment where employees feel valued, respected, and empowered to manage their reproductive health needs. By prioritizing inclusivity and support in reproductive health policies, employers can promote employee well-being, productivity, and engagement in the workplace.
#
# Q3: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Introduction:
# Developing and implementing reproductive and fertility health policies in the workplace is crucial for ensuring inclusivity and support for all employees. In this report, we will discuss the best practices to follow in order to create policies that are culturally sensitive, inclusive of diverse religious beliefs, promote education and awareness, improve access and affordability, ensure legal compliance, and provide flexible work and leave policies to support employees' reproductive health needs.
#
# Cultural Sensitivity:
# One of the best practices for developing reproductive health policies in the workplace is to adapt them based on regional attitudes towards reproductive healthcare. Different cultures may have varying beliefs and norms surrounding reproductive health, so it is important to take these into consideration when crafting policies. By being culturally sensitive, organizations can ensure that their policies are respectful and inclusive of all employees, regardless of their cultural background.
#
# Religious Inclusivity:
# Another important aspect to consider when developing reproductive health policies is religious inclusivity. Organizations should offer flexible benefits that align with diverse religious beliefs. This could include accommodating time off for religious holidays or religious practices related to reproductive health. By being inclusive of diverse religious beliefs, organizations can create a supportive environment for all employees.
#
# Education & Awareness:
# Providing education and awareness around reproductive health is essential for normalizing discussions and reducing stigma. Organizations can offer workshops, training sessions, and peer support groups to help employees feel more comfortable discussing reproductive health issues. By promoting education and awareness, organizations can empower employees to take control of their reproductive health and seek the support they need.
#
# Access & Affordability:
# Ensuring access to reproductive healthcare is another key best practice for developing workplace policies. Organizations can partner with healthcare providers and NGOs to expand access in resource-limited areas. By offering affordable and accessible reproductive health services, organizations can ensure that all employees have the support they need to take care of their reproductive health needs.
#
# Legal Compliance:
# It is essential for organizations to ensure that their reproductive health policies align with local labor laws and healthcare regulations. By staying compliant with legal requirements, organizations can avoid potential legal issues and ensure that their policies are fair and equitable for all employees. Legal compliance is a critical component of developing inclusive and supportive reproductive health policies in the workplace.
#
# Flexible Work and Leave Policies:
# Finally, providing flexible work and leave policies is crucial for supporting employees' reproductive health needs. Organizations should address time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. By offering flexible policies, organizations can support employees during challenging times and ensure that they have the time and support they need to take care of their reproductive health needs.
#
# Conclusion:
# In conclusion, developing and implementing reproductive and fertility health policies in the workplace requires a holistic approach that focuses on cultural sensitivity, religious inclusivity, education and awareness, access and affordability, legal compliance, and flexible work and leave policies. By following these best practices, organizations can create a supportive and inclusive environment that prioritizes the reproductive health needs of all employees.
#
# Q4: Write a 500 word report on what are the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees?
# Answer: Introduction:
#
# Creating an effective reproductive and fertility health policy for the workplace is crucial in promoting inclusivity and support for all employees. By understanding the key components that should be incorporated into the policy, employers can ensure that it is clear, comprehensive, and impactful. This report will outline the essential elements that should be included in a workplace reproductive and fertility health policy to support diverse religious perspectives and address various reproductive health-related concerns.
#
# Key Components of a Workplace Reproductive and Fertility Health Policy:
# 1. Inclusive Language: The policy should use inclusive language that respects diverse religious perspectives and beliefs. It is essential to acknowledge that employees may have different views on reproductive health issues such as IVF, abortion, and pregnancy loss. By using inclusive language, employers can create a supportive and respectful environment for all employees.
#
# 2. Flexible Work and Leave Policies: The policy should include provisions for flexible work and leave policies to address time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. Employees should have the option to take time off for medical appointments related to reproductive health without facing discrimination or negative consequences. Flexible work arrangements, such as telecommuting or adjusted work hours, can also help employees manage their reproductive health needs while balancing work responsibilities.
#
# 3. Confidentiality and Privacy: The policy should outline procedures for maintaining confidentiality and privacy regarding employees' reproductive health information. Employees should feel comfortable discussing their reproductive health concerns with their supervisors or HR professionals without fear of judgment or disclosure of sensitive information. By ensuring confidentiality and privacy, employers can create a safe and supportive environment for employees to seek help and support.
#
# 4. Education and Awareness Programs: The policy should include provisions for education and awareness programs to help employees understand reproductive health issues and access resources for support. Employers can provide training sessions, workshops, or informational materials on topics such as fertility treatments, pregnancy loss, menopause, and family planning. By increasing awareness and knowledge about reproductive health, employers can empower employees to make informed decisions about their reproductive health needs.
#
# 5. Supportive Workplace Culture: The policy should promote a supportive workplace culture that values diversity, inclusivity, and empathy. Employers should foster open communication, respect, and understanding among employees to create a positive work environment for everyone. By promoting a supportive workplace culture, employers can help employees feel valued, respected, and supported in managing their reproductive health needs.
#
# Conclusion:
#
# In conclusion, a workplace reproductive and fertility health policy should include key components such as inclusive language, flexible work and leave policies, confidentiality and privacy procedures, education and awareness programs, and a supportive workplace culture. By incorporating these elements into the policy, employers can ensure inclusivity and support for all employees, regardless of their religious perspectives or reproductive health-related concerns. Creating a comprehensive and impactful policy will help promote a healthy and supportive work environment where employees feel valued, respected, and empowered to manage their reproductive health needs effectively.

# %%
with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)

ragas_data = []
for ref, pred in zip(qa_data, llm_results):
    ragas_data.append({
        "question": ref["question"],
        "answer": pred["answer"],
        "contexts": [pred["context_used"]],
        "ground_truth": ref["ground_truth_answer"]
    })

from datasets import Dataset
ragas_dataset = Dataset.from_list(ragas_data)

# Evaluate
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness
)
from ragas import evaluate

evaluation_scores = evaluate(
    ragas_dataset,
    metrics=[answer_relevancy, context_precision, context_recall, faithfulness],
    llm=llm
)

print(evaluation_scores)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# {'answer_relevancy': 0.9156, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 0.8922}
