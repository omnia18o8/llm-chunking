# %%
from openai import OpenAI
import voyageai as vo  
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client_vo = vo.Client(api_key=os.getenv("VOYAGE_API_KEY"))  
chat_evaluator_model = "gpt-5-nano"
chat_judge_model = "gpt-4.1-mini"
embedding_model = "voyage-3-large"

# %%
k = 3
a = 0.6 #alpha for semantic (1.0) and keyword search (0.0)
lambda_parameter = 0.7 #lambda for diversity (1.0 is all diverse) and 0.0 is chunks are the same

# %%
import os
from ingestion import load_documents
base_path = os.path.abspath("..")
md_texts = load_documents(base_path)

# %%
from sentence_transformers import SentenceTransformer
import re

model = SentenceTransformer("all-MiniLM-L6-v2") #or "all-mpnet-base-v2"

all_text = "\n".join(doc["text"] for doc in md_texts)

paragraphs = re.split(r'\n\s*\n+', all_text)
paragraphs = [p.strip() for p in paragraphs if len(p.strip()) > 100]

# %%
print(len(paragraphs), "total chunks created")
print(paragraphs[1])
# Out:
# 352 total chunks created
# Define reproductive health in the workplace: not just fertility, but encompassing menstrual health, menopause, and other reproductive challenges.

# %%
# import numpy as np

# chunk_texts = [c.page_content for c in all_chunks]

# resp = client_vo.contextualized_embed(
#     inputs=[[text] for text in chunk_texts],  # list of lists
#     model=embedding_model,
#     input_type="document",
# )
# chunk_embeddings = np.array([r.embeddings[0] for r in resp.results], dtype=np.float32)
# chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

import numpy as np

chunk_texts = [c for c in paragraphs]

resp = client_vo.embed(
    chunk_texts,  # list of lists
    model=embedding_model,
    input_type="document",
)
chunk_embeddings = np.array(
    resp.embeddings,
    dtype=np.float32
)
chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

# %%
from rag import response_llm, embed_query
import json

with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)
questions = [q["question"] for q in qa_data]

# Run
llm_results = response_llm(
    questions=questions,
    client=client,
    chat_model=chat_evaluator_model,
    chunk_embeddings=chunk_embeddings,
    chunk_texts=chunk_texts,
    embed_query=embed_query,
    k=k,
    alpha=a,
    lambda_param=lambda_parameter
)
# Out:
# Q1: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Best practices for developing and implementing reproductive and fertility health policies in the workplace
#
# A well-structured reproductive and fertility health guide is foundational to an inclusive workplace. Such guidance helps reduce stigma around reproductive health, supports employee well-being, and contributes to higher retention. When policies are thoughtfully designed and implemented, they signal to all employees that their health needs are acknowledged and accommodated.
#
# Key practices
#
# - Cultural sensitivity: Develop policies by adapting them to regional attitudes toward reproductive healthcare. Recognize that perceptions and norms around reproductive health can vary by location, and tailor guidance to fit these contexts. This approach helps ensure that policies are relevant, respectful, and more readily accepted by employees in different regions.
#
# - Religious inclusivity: Offer flexible benefits that align with diverse religious beliefs. By providing options that accommodate varying religious perspectives, policies become more inclusive and resonate with a broader employee base. Flexibility in benefits supports employees’ choices without creating unnecessary barriers or discomfort.
#
# - Education and awareness: Invest in education through workshops, training, and peer support to normalize discussions about reproductive health. Providing ongoing learning opportunities helps reduce stigma, increases understanding among colleagues, and creates a more supportive workplace culture where employees feel comfortable seeking guidance and accommodations.
#
# - Access and affordability: Partner with healthcare providers and NGOs to expand access in resource-limited areas. Building collaboration networks can improve the availability of reproductive and fertility health services for employees who may face financial or logistical barriers. Such partnerships extend the reach and impact of the policies beyond the employer’s immediate resources.
#
# - Legal compliance: Ensure policies align with local labor laws and healthcare regulations. Maintaining compliance protects the organization and employees, and helps ensure policies are enforceable and trustworthy. It also supports consistent application across different jurisdictions and units.
#
# - Flexible work and leave policies: Address time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. Flexible scheduling and leave options acknowledge the realities of reproductive health journeys and enable employees to manage treatment, recovery, or transition without undue hardship. This flexibility reinforces a supportive environment for all stages of reproductive health.
#
# Implementation considerations
#
# - Develop or revise a comprehensive guide that articulates available benefits, leave options, and procedures for accessing support. A clear, accessible guide reduces confusion and fosters consistent application.
#
# - Align communications and training with the overarching goal of inclusivity. Regular education reinforces the importance of reproductive health as part of overall well-being and demonstrates organizational commitment.
#
# - Monitor and review policies to ensure ongoing relevance and effectiveness. While the provided guidance emphasizes adaptation to regional attitudes and legal requirements, regular review helps keep policies current with changing laws, norms, and employee needs.
#
# Conclusion
#
# In sum, best practices for workplace reproductive and fertility health policies center on creating an inclusive, stigma-reducing environment through culturally sensitive and religiously inclusive benefits, proactive education, expanded access, strict legal alignment, and flexible work and leave options. When organizations implement these elements coherently, they enhance inclusivity, support employee well-being, and improve retention, contributing to a healthier and more engaged workforce.
#
# Q2: Write a 500 word report on what are the best practices for developing and applying reproductive and fertility health policies in the workplace to ensure inclusivity and support for employees?
# Answer: Best practices for developing and applying reproductive and fertility health policies in the workplace
#
# A well-structured reproductive and fertility health guide can enhance workplace inclusivity, reduce stigma, and improve employee well-being and retention. To achieve these outcomes, organizations should ground policies in cultural sensitivity, religious inclusivity, education, access, and legal compliance, while also implementing flexible work and leave provisions that address reproductive health concerns.
#
# Key practice areas
#
# - Cultural sensitivity and regional alignment
#   - Adapt policies based on regional attitudes toward reproductive healthcare. Recognize that perceptions and norms vary, and tailor guidance so it is respectful and relevant in each location.
#
# - Religious inclusivity and flexible benefits
#   - Offer flexible benefits that align with diverse religious beliefs. Designing benefits with inclusivity in mind ensures employees feel supported regardless of faith tradition.
#
# - Education, awareness, and normalization
#   - Provide workshops, training, and peer support to normalize discussions around reproductive and fertility health. Education helps reduce stigma and fosters a more open and supportive workplace culture.
#
# - Access and affordability
#   - Partner with healthcare providers and NGOs to expand access in resource-limited areas. Collaboration can help extend coverage and resources for employees who might otherwise face barriers to care.
#
# - Legal compliance and policy alignment
#   - Ensure policies align with local labor laws and healthcare regulations. Maintaining legal compliance is essential to protect both employees and the organization and to ensure policy effectiveness across regions.
#
# - Flexible work and leave policies
#   - Address time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. Flexible work arrangements and leave provisions support employees during diverse stages of reproductive health without compromising work responsibilities.
#
# Implementation considerations
#
# - Policy development and consistency
#   - Build policies that reflect the combination of cultural sensitivity, religious inclusivity, education, access, and legal compliance. Consistency across the organization helps create a predictable and trustworthy environment for employees.
#
# - Communication and accessibility
#   - Clearly communicate available policies and benefits, including how to request leave or accommodations. Ensure information is accessible to all employees, regardless of location or role.
#
# - Stakeholder involvement
#   - Involve HR, leadership, employee resource groups, and healthcare partners in policy design and rollout. Broad collaboration helps ensure policies are practical, comprehensive, and widely accepted.
#
# - Monitoring impact and continuous improvement
#   - Use the key takeaway as a guiding expectation: a well-structured guide should promote inclusivity, reduce stigma, and support well-being and retention. Periodically review and refine policies to maintain alignment with evolving regional attitudes, medical advances, and regulatory changes.
#
# Expected outcomes
#
# - Enhanced inclusivity and reduced stigma around reproductive and fertility health topics.
# - Improved employee well-being and potentially higher retention and satisfaction.
# - Greater access and affordability of reproductive health resources for employees, including those in resource-limited areas.
# - Compliance with local labor laws and healthcare regulations, reducing legal risk and ensuring policy legitimacy.
#
# In summary, best practices combine culturally and religiously sensitive policy design with concrete actions: adapt regionally, offer inclusive benefits, educate and normalize discussions, expand access through partnerships, ensure legal compliance, and provide flexible work and leave options for fertility treatments, pregnancy loss, menopause, and other reproductive health concerns. Implemented thoughtfully, these practices support a more inclusive workplace and contribute to better employee well-being and retention.
#
# Q3: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Developing and implementing reproductive and fertility health policies in the workplace is essential for inclusivity, reducing stigma, and improving employee well-being and retention. A well-structured reproductive and fertility health guide serves as the backbone for these efforts and helps ensure consistent, fair treatment across the organization.
#
# Cultural sensitivity is a foundational best practice. Policies should be adapted based on regional attitudes toward reproductive healthcare, recognizing that needs and norms vary by location. By tailoring approaches to local contexts, organizations can foster trust and relevance, increasing the likelihood that employees will engage with available support rather than feeling misunderstood or marginalized.
#
# Religious inclusivity is another core element. Offering flexible benefits that align with diverse religious beliefs allows employees to choose options that fit their values while still accessing needed care. Flexible benefits signal respect for personal conscience and help prevent unintended barriers to care.
#
# Education and awareness play a critical role in normalizing conversations around reproductive health. Providing workshops, training, and peer support creates safe spaces for dialogue, disseminates accurate information, and reduces stigma. When employees feel informed and supported, they are more likely to seek care and participate in company programs.
#
# Access and affordability must be addressed to ensure equitable support, especially in resource-limited areas. Partnering with healthcare providers and NGOs can expand access to reproductive and fertility services beyond what a single organization can offer. Such partnerships help close gaps in coverage and reduce financial barriers that prevent employees from receiving timely care.
#
# Legal compliance is essential to maintain legitimacy and protect both employees and the organization. Policies should align with local labor laws and healthcare regulations, ensuring that rights are protected while operations remain compliant. Regular review of legal requirements helps preempt disputes and adapt to new regulations.
#
# Flexible work and leave policies are a concrete mechanism to support employees through fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. By allowing appropriate time off and accommodations, organizations acknowledge the realities of these experiences and prevent career disruption due to health needs.
#
# Taken together, these best practices enable the creation of a comprehensive program that addresses the diverse needs of all employees. The goal is not only compliance but also a culture of inclusion where individuals feel seen, respected, and supported. This approach leads to better well-being, stronger engagement, and higher retention, fulfilling the core takeaway that a well-structured guide enhances inclusivity, reduces stigma, and improves outcomes for both workers and the organization.
#
# Together, these practices form a comprehensive framework for developing and implementing reproductive and fertility health policies that truly support all employees. By embedding cultural sensitivity, religious inclusivity, education, access, and legal compliance into the policy framework, organizations create a healthier, more equitable workplace. The outcome is not only compliance but also a workplace culture where discussions around reproductive health are normalized, stigma is reduced, and employee well-being and engagement improve. In turn, this improves retention and aligns with the key takeaway: a well-structured guide enhances inclusivity, reduces stigma, and strengthens the organization as a whole.
#
# Q4: Write a 500 word report on what are the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees?
# Answer: This report identifies the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees. Grounded in the aim that a well-structured guide enhances workplace inclusivity, reduces stigma, and improves employee well-being and retention, the policy should address a broad range of reproductive health needs and align with the organization's values and legal obligations.
#
# Key components
#
# - Flexible Work and Leave Policies
#   - The policy must address time off and accommodations for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. This ensures employees can access needed time away or adjustments without compromising their careers or financial security, thereby supporting well-being and retention.
#
# - Cultural Sensitivity
#   - Adapt policies based on regional attitudes toward reproductive healthcare. Recognizing that beliefs and norms vary by location helps ensure the policy is practical, respectful, and effective across different settings.
#
# - Religious Inclusivity
#   - Offer flexible benefits that align with diverse religious beliefs. By incorporating varied religious perspectives into the benefits and accommodations, the policy supports employees’ values and reduces potential conflict between personal beliefs and workplace requirements.
#
# - Education & Awareness
#   - Provide workshops, training, and peer support to normalize discussions around reproductive health. Education helps reduce stigma, improve understanding among colleagues, and empower employees to seek and receive appropriate support.
#
# - Access & Affordability
#   - Partner with healthcare providers and NGOs to expand access in resource-limited areas. Building collaborations can improve availability of services and coverage, making reproductive health resources more affordable and accessible for a broader employee base.
#
# - Legal Compliance
#   - Ensure policies align with local labor laws and healthcare regulations. A compliant framework protects both employees and the organization, providing clear guidance on rights, responsibilities, and any required procedures.
#
# Additional considerations implied by these components
#
# - Inclusivity and well-being focus
#   - The overarching objective is to create a policy that supports all employees’ reproductive health needs, contributing to a more inclusive and supportive workplace culture.
#
# - Stigma reduction and retention
#   - By combining flexible policies, sensitivity to regional and religious diversity, and ongoing education, the policy aims to normalize conversations around reproductive health, reduce stigma, and promote longer-term employee retention.
#
# - Practical implementation awareness
#   - While not explicitly detailed in the components, successful adoption relies on clear communication of policies, accessible resources, and ongoing collaboration with healthcare partners to ensure services are reachable and relevant to employees in various locations.
#
# In summary, an effective workplace reproductive and fertility health policy should integrate flexible leave and accommodation options, cultural and religious sensitivity, proactive education, enhanced access through partnerships, and strict legal compliance. Together, these components support inclusivity, reduce stigma, and improve employee well-being and retention.

# %%
with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)

ragas_data = []
for ref, pred in zip(qa_data, llm_results):
    ragas_data.append({
        "question": ref["question"],
        "answer": pred["answer"],
        "contexts": [pred["context_used"]],
        "ground_truth": ref["ground_truth_answer"]
    })

from datasets import Dataset
ragas_dataset = Dataset.from_list(ragas_data)

# Evaluate
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name=chat_judge_model, temperature=0)

from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness
)
from ragas import evaluate

evaluation_scores = evaluate(
    ragas_dataset,
    metrics=[answer_relevancy, context_precision, context_recall, faithfulness],
    llm=llm
)

print(evaluation_scores)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# {'answer_relevancy': 0.9282, 'context_precision': 1.0000, 'context_recall': 0.5417, 'faithfulness': 0.6475}
