# %%
from openai import OpenAI
import voyageai as vo  
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client_vo = vo.Client(api_key=os.getenv("VOYAGE_API_KEY"))  
chat_evaluator_model = "gpt-5-nano"
chat_judge_model = "gpt-4.1-mini"
embedding_model = "voyage-3-large"

# %%
k = 3
a = 0.6 #alpha for semantic (1.0) and keyword search (0.0)
lambda_parameter = 0.7 #lambda for diversity (1.0 is all diverse) and 0.0 is chunks are the same

# %%
import os
from ingestion import load_documents
base_path = os.path.abspath("..")
md_texts = load_documents(base_path)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base",
    chunk_size=1500,
    chunk_overlap=150
)
all_chunks = []

for doc in md_texts:
    chunks = splitter.create_documents([doc["text"]])
    for c in chunks:
        c.metadata = {"source": doc["file"]}  # tag chunk with original file name (not necessary here but just in case i think)
    all_chunks.extend(chunks)
print(len(all_chunks), "total chunks created")
#print(all_chunks[0].page_content)
# Out:
# 37 total chunks created

# %%
# import numpy as np

# chunk_texts = [c.page_content for c in all_chunks]

# resp = client_vo.contextualized_embed(
#     inputs=[[text] for text in chunk_texts],  # list of lists
#     model=embedding_model,
#     input_type="document",
# )
# chunk_embeddings = np.array([r.embeddings[0] for r in resp.results], dtype=np.float32)
# chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

import numpy as np

chunk_texts = [c.page_content for c in all_chunks]

resp = client_vo.embed(
    chunk_texts,  # list of lists
    model=embedding_model,
    input_type="document",
)
chunk_embeddings = np.array(
    resp.embeddings,
    dtype=np.float32
)
chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

# %%
from rag import response_llm, embed_query
import json

with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)
questions = [q["question"] for q in qa_data]

# Run
llm_results = response_llm(
    questions=questions,
    client=client,
    chat_model=chat_evaluator_model,
    chunk_embeddings=chunk_embeddings,
    chunk_texts=chunk_texts,
    embed_query=embed_query,
    k=k,
    alpha=a,
    lambda_param=lambda_parameter
)
# Out:
# Q1: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Best practices for developing and implementing workplace reproductive and fertility health policies that are inclusive and supportive
#
# 1) Start with clear purpose and guided process
# - Define the policy’s purpose: to support employees facing reproductive and fertility health challenges, reduce mismanagement and litigation risk, and align with well-being and inclusion values.
# - Use a structured, cross-functional process: Step 1 review existing data (surveys, interviews); Step 2 identify gaps with a 5Ps Framework; Step 3 engage stakeholders across HR, legal, and communications; Step 4 draft clear policy elements (fertility treatment support, menopause-related flexibility, dedicated health leave); Step 5 communicate the guide in clear, accessible language.
# - Involving employees in policy development increases benefit uptake (up to 30%).
#
# 2) Build a well-structured, actionable guide
# - Ensure the guide is clear, accessible, and easy to navigate for employees, managers, and HR.
# - Make policies actionable and policy language straightforward—outline who qualifies, what support exists, how to access it, and expected timelines.
# - Present the guide in multiple formats (digital, print, audio) to maximize accessibility.
#
# 3) Define core policy areas with practical examples
# - Flexible work and leave: include time off for fertility treatments, pregnancy loss, menopause, and other reproductive health needs; establish flexible working during medical treatment or symptom management.
# - Health benefits and financial support: detail available coverage for fertility treatments, consultations, therapy, and related services; consider subsidies or employer-paid elements where feasible.
# - Reasonable accommodations: provide workplace adjustments such as ergonomic supports, private lactation spaces, or remote work options.
# - Explicit fertility and family-forming benefits (IVF, surrogacy, egg freezing), pregnancy loss leave, menstrual health accommodations, and menopause support.
#
# 4) Prioritize inclusivity, accessibility, and stigma reduction
# - Include all genders, sexual orientations, and family structures; address cultural and religious considerations.
# - Provide awareness and education to normalize reproductive health discussions (workshops, webinars, peer support).
# - Offer various access points: quiet treatment spaces, workload adjustments during challenging periods, mental health and peer support groups.
# - Establish confidential HR support and an internal ERG or peer networks to reduce stigma and foster safe conversations.
#
# 5) Equip managers and HR with the right skills and obligations
# - Train managers on sensitive conversations, recognizing and responding to reproductive health needs, and providing accommodations.
# - Communicate legal obligations and employee rights; emphasize psychological safety and confidentiality.
# - Implement practical tools: confidential reporting systems, manager check-ins, and agencies or experts available for consultations.
#
# 6) Implement with a clear rollout and measurement plan
# - Use concrete updates as proof points (e.g., paid fertility leave, miscarriage leave, and flexible schedules for menstrual health).
# - Develop an internal communication plan and a timing roadmap; pilot programs if appropriate.
# - Measure uptake and impact (benefits usage, retention, engagement, and productivity). Tie outcomes to ROI where possible.
#
# 7) Integrate global and cultural considerations
# - Adapt policies to regional attitudes toward reproductive health; ensure alignment with local labor laws and healthcare regulations.
# - Provide education and awareness campaigns to address cultural sensitivities; partner with healthcare providers or NGOs to improve access and affordability in resource-limited contexts.
#
# 8) Leverage external expertise and example case studies
# - Learn from real-world cases (Unilever, Google, PwC, NatWest, Co-op) to understand practical benefits, challenges, and outcomes like improved retention, reduced stigma, and better manager support.
# - Use available resources (e.g., We Are Eden’s online course, policy audits, and expert-led webinars) to structure policy design, training, and ongoing support.
#
# 9) Continuous refinement
# - Reassess practices regularly, compare against self-assessments, and refine the guide accordingly.
# - Keep leadership engaged, budget aligned, and ROI metrics clear to sustain momentum and culture change.
#
# By following these practices, organizations can design reproductive and fertility health policies that are inclusive, supportive, and aligned with broader DEI and well-being goals, while delivering measurable improvements in engagement, retention, and productivity.
#
# Q2: Write a 500 word report on what are the best practices for developing and applying reproductive and fertility health policies in the workplace to ensure inclusivity and support for employees?
# Answer: Best practices for developing and applying workplace reproductive and fertility health policies
#
# Purpose and strategic alignment
# - Define the purpose of the guide as supporting employees dealing with reproductive and fertility health challenges. Align policy development with company values on well-being and inclusion and with business strategy and employee needs.
# - Reflect your organization’s culture and workforce demographics to ensure relevance and uptake.
#
# Data-informed, collaborative design
# - Begin with preparatory work: explain the need for a customized guide and how it reflects your culture and workforce.
# - Use a step-by-step approach: review existing data (surveys, exit interviews, focus groups) to identify gaps; apply the 5Ps Framework to prioritize policy elements; engage stakeholders across HR, legal, and communications.
# - Involve employees in policy development; evidence suggests co-creation can increase benefit uptake by up to 30%.
#
# Policy structure and core elements
# - Core policies should be clear, actionable, and accessible. Include:
#   - Flexible work and leave policies for fertility treatments, pregnancy loss, menopause, and other reproductive health needs.
#   - Health benefits and insurance details, including financial support for fertility treatments, consultations, and therapy.
#   - Reasonable accommodations (ergonomic support, private lactation spaces, remote or flexible work options).
#   - Fertility and family-forming benefits (IVF, surrogacy, egg freezing) and menstrual, menopause, and reproductive health leave.
#   - Access to expert support (coaching, peer groups, digital tools) and information resources.
# - Communicate policies in clear, accessible language and consider multiple formats (digital, print, audio).
#
# Inclusivity, accessibility, and culture
# - Ensure the guide is inclusive of all genders, sexual orientations, and family structures; address cultural and religious considerations.
# - Provide workplace adjustments and support (quiet treatment spaces, workload adjustments, mental health and peer support groups).
# - Launch awareness initiatives (webinars, ERGs, partnerships with external reproductive health specialists) to normalize discussions and reduce stigma.
# - Embed inclusivity into DEI and Wellbeing strategies; foster psychological safety and confidentiality in health discussions.
#
# Manager and HR guidance
# - Train managers to handle sensitive conversations with empathy and respect; clarify legal obligations and employee rights.
# - Provide confidential HR support systems so employees can seek help without disclosing sensitive information to direct managers.
# - Equip HR and leaders with practical skills to recognize needs, respond appropriately, and remove barriers to access.
#
# Implementation, governance, and evaluation
# - Implement concrete updates (e.g., paid fertility leave, miscarriage leave, flexible working during menstrual health challenges) and communicate them organization-wide.
# - Establish budget allocation and ROI metrics to show impact; plan for ongoing review and refinement.
# - Use pilot and rollout strategies with awareness campaigns and ongoing support services (peer networks, expert-led webinars) to sustain momentum.
# - Treat policy development as iterative: revisit self-assessments and compare against the new framework; refine based on feedback and outcomes.
#
# Global considerations and evidence
# - Adapt policies to regional attitudes toward reproductive health; respect religious beliefs; ensure legal compliance with local labor laws and healthcare regulations.
# - Where resources are limited, partner with NGOs or external providers to expand access and affordability.
#
# Evidence and outcomes
# - Case examples illustrate benefits: Unilever’s menopause and fertility supports improving retention; Google’s inclusive family-forming benefits boosting satisfaction and DEI scores; Co-op’s flexible policies reducing absenteeism; PwC’s pregnancy loss support improving return-to-work; NatWest’s manager training enhancing manager-employee relationships.
#
# Next steps
# - Enroll in specialized online courses or consultancies to tailor policies to your workforce.
# - Engage employees with expert-led support to drive culture change and real inclusivity.
#
# Q3: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Best practices for developing and implementing workplace reproductive and fertility health policies to ensure inclusivity and support
#
# Executive overview
# A well-designed reproductive and menstrual health policy helps employees access support, reduces mismanagement risk, and strengthens inclusion, productivity, and legal compliance. Policies should be data-driven, clearly structured, and aligned with business strategy, while reflecting diverse employee needs and cultures.
#
# Core best practices
#
# 1) Start with data, gaps, and broad buy-in
# - Review existing data (employee surveys, exit interviews, focus groups) to understand awareness and needs.
# - Use the 5Ps Framework to identify gaps: Policies, People, Processes, Programs, and Performance.
# - Engage stakeholders across HR, legal, and communications early, then draft policy elements (e.g., fertility treatment support, menopause flexibility, dedicated health leave).
# - Involve employees in policy development; research shows this can boost benefit uptake by up to 30%.
#
# 2) Build a clear, actionable policy structure
# - Ensure the guide is easy to navigate for employees, managers, and HR, with explicit policies and support mechanisms.
# - Include core policy areas: flexible work and leave for fertility treatments, pregnancy loss, menopause and menstrual health; health benefits and financial support for treatments; and reasonable accommodations (ergonomic support, lactation rooms, remote work).
# - Provide specific leave and benefits details (e.g., fertility leave, miscarriage leave, menstrual health accommodations) and how to access them.
#
# 3) Design for inclusivity, accessibility, and cultural sensitivity
# - Make policies inclusive of all genders, sexual orientations, and family structures; address cultural and religious considerations.
# - Offer the guide in multiple formats (digital, print, audio) to maximize accessibility.
# - Provide practical workplace adjustments (quiet spaces, workload management during treatment, mental health and peer support groups).
# - Consider global and cultural contexts: adapt policies for regional attitudes, religious beliefs, and access to care; include education and awareness initiatives to reduce stigma.
#
# 4) Integrate leadership, DEI, and wellbeing
# - Embed reproductive health into DEI and wellbeing strategies; leaders should model openness and psychological safety.
# - Allocate budget and establish ROI metrics to demonstrate value.
# - Provide manager training to handle sensitive conversations, recognize needs, and respond with support.
# - Create confidential support channels (HR support systems, ERGs, external experts) to protect privacy and trust.
#
# 5) Deliver comprehensive policy content with practical programs
# - Core benefits: fertility and family-forming support (IVF, surrogacy, egg freezing), menstrual and menopause leave, and access to expert coaching or digital tools.
# - Support mechanisms: peer groups, expert-led education, and lived-experience resources to guide policy design.
# - Example policy elements seen in practice: paid fertility leave (e.g., 5 days), paid miscarriage leave (e.g., 2 weeks), flexible working for menstrual health, and menopause support with adjustments.
#
# 6) Implementation, rollout, and culture change
# - Implement policy updates, communicate them clearly, and train managers.
# - Launch awareness and support activities (well-being webinars; partnerships with external reproductive health specialists; Employee Resource Groups).
# - Integrate with existing wellness and DEI programs; use pilots and phased rollouts where appropriate.
#
# 7) Measure, refine, and scale
# - Assess readiness with self-assessment tools; track outcomes such as uptake, retention, and productivity.
# - Gather feedback, refine the policy, and scale successful components across regions.
# - Use case studies and benchmarks to demonstrate impact and guide improvements.
#
# Real-world illustrations and leverage points
# - Case studies show benefits in retention, engagement, and DEI: Unilever (menopause and fertility support); Google (comprehensive family-forming benefits); Co-op (flexible working for endometriosis); PwC (pregnancy loss and fertility support); NatWest (manager training and support networks).
# - Practical steps used by organizations include: paid fertility leave, miscarriage leave, flexible work during health challenges, and dedicated support networks.
#
# Resources
# - We Are Eden offers an online course, consulting, and employee support services to design and implement these policies and programs.
#
# In summary, the best practice approach combines data-driven design, clear and inclusive policy content, leadership-led culture change, accessible delivery, and robust evaluation to create a workplace that meaningfully supports reproductive and fertility health for all employees.
#
# Q4: Write a 500 word report on what are the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees?
# Answer: Key components to include in a workplace reproductive and fertility health policy (for inclusivity and broad employee support)
#
# Introduction
# A well-designed policy helps employees access essential support while ensuring the organization upholds inclusion, productivity, and legal compliance. The policy should be accessible, evolving, and aligned with broader DEI and wellbeing goals.
#
# 1) Core policies to support employees facing reproductive health challenges
# - Flexible work and leave policies: Provide time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related concerns. Include guidance on how to apply for leave and how leave interacts with workload and coverage.
# - Health benefits and insurance: Detail available health coverage, workplace benefits, and financial support for fertility treatments, consultations, and therapy. Clarify what is covered and how to access benefits.
# - Reasonable accommodations: Outline workplace adjustments such as ergonomic support, private lactation rooms, and remote work options. Include processes for requesting accommodations and how they are evaluated.
#
# 2) Clear structure and accessible processes
# - Simple, clear language: Use non-medical terms and inclusive terminology to ensure comprehension across diverse employee groups.
# - Step-by-step guidance: Break down processes such as applying for leave, accessing HR support, and confidentiality protocols into actionable steps.
# - Who to contact: Provide clear points of contact within HR, employee assistance programs, and external resources so employees know where to turn for support.
#
# 3) Inclusivity and accessibility
# - Inclusive scope: Ensure the policy is inclusive of all genders, sexual orientations, and family structures. Address the needs of diverse employees and family-building scenarios.
# - Cultural and religious considerations: Acknowledge and accommodate differing beliefs and practices related to reproductive health.
# - Accessible formats: Offer the guide in multiple formats (digital, print, audio) to maximize accessibility for all employees.
#
# 4) Addressing workplace culture and reducing stigma
# - Education and awareness: Provide education on reproductive health-related biases and how they impact employees, with a focus on reducing stigma.
# - Manager and HR guidance: Outline strategies for managers and HR to foster an open, supportive culture, including how to respond to disclosures with care and confidentiality.
# - Confidentiality and psychological safety: Emphasize the importance of protecting sensitive information and creating a safe space for discussions about reproductive health.
#
# 5) Implementation, communication, and governance
# - Clear communication and contacts: Include ongoing communication channels and internal/external resources so employees know where to get help.
# - Accessibility and evolving guidance: Ensure the policy is easy to navigate, regularly updated, and supported by downloadable handouts or checklists with actionable steps.
# - Evaluation and gaps analysis: Encourage regular assessment of current policies to identify gaps and opportunities for improvement, aligning with DEI and wellbeing objectives.
#
# 6) Supporting elements and practical considerations
# - Specific policy areas to outline: Fertility leave, miscarriage leave, menstrual health accommodations, flexible working policies, and access to expert support (coaching, peer groups, digital tools).
# - Operational supports: Physical and environmental adjustments (quiet spaces, workload management), and mental health support options (peer groups, therapy) as part of a holistic approach.
# - Employee resources and next steps: Internal contacts for support and external expert resources to complement benefits and services.
#
# In sum, an inclusive reproductive and fertility health policy should articulate concrete leave and accommodation options, clear benefit details, accessible and jargon-free guidance, contact points, and commitments to reducing stigma—all while ensuring cultural sensitivity, multiple access formats, and regular policy review.

# %%
with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)

ragas_data = []
for ref, pred in zip(qa_data, llm_results):
    ragas_data.append({
        "question": ref["question"],
        "answer": pred["answer"],
        "contexts": [pred["context_used"]],
        "ground_truth": ref["ground_truth_answer"]
    })

from datasets import Dataset
ragas_dataset = Dataset.from_list(ragas_data)

# Evaluate
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name=chat_judge_model, temperature=0)

from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness
)
from ragas import evaluate

evaluation_scores = evaluate(
    ragas_dataset,
    metrics=[answer_relevancy, context_precision, context_recall, faithfulness],
    llm=llm
)

print(evaluation_scores)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# {'answer_relevancy': 0.9283, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 0.9782}
