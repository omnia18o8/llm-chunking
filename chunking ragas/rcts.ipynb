# %%
from openai import OpenAI
import voyageai as vo  
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client_vo = vo.Client(api_key=os.getenv("VOYAGE_API_KEY"))  
chat_model = "gpt-3.5-turbo"
embedding_model = "voyage-context-3"

# %%
k = 3
a = 0.6 #alpha for semantic (1.0) and keyword search (0.0)
lambda_parameter = 0.7 #lambda for diversity (1.0 is all diverse) and 0.0 is chunks are the same

# %%
import os
from ingestion import load_documents
base_path = os.path.abspath("..")
md_texts = load_documents(base_path)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base",
    chunk_size=1500,
    chunk_overlap=150
)
all_chunks = []

for doc in md_texts:
    chunks = splitter.create_documents([doc["text"]])
    for c in chunks:
        c.metadata = {"source": doc["file"]}  # tag chunk with original file name (not necessary here but just in case i think)
    all_chunks.extend(chunks)
print(len(all_chunks), "total chunks created")
#print(all_chunks[0].page_content)
# Out:
# 37 total chunks created

# %%
import numpy as np

chunk_texts = [c.page_content for c in all_chunks]

resp = client_vo.contextualized_embed(
    inputs=[[text] for text in chunk_texts],
    model=embedding_model, 
    input_type="document"
)

chunk_embeddings = np.array(
    [r.embeddings[0] for r in resp.results],
    dtype=np.float32
)

chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

# %%
from rag import response_llm, embed_query
import json

with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)
questions = [q["question"] for q in qa_data]

# Run
llm_results = response_llm(
    questions=questions,
    client=client,
    chat_model=chat_model,
    chunk_embeddings=chunk_embeddings,
    chunk_texts=chunk_texts,
    embed_query=embed_query,
    k=k,
    alpha=a,
    lambda_param=lambda_parameter
)
# Out:
# Q1: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Developing and implementing reproductive and fertility health policies in the workplace is crucial to ensure inclusivity and support for all employees. By following best practices, organizations can create a welcoming and supportive environment that addresses the diverse needs of their workforce. Here are some key best practices to consider:
#
# 1. Inclusivity and Accessibility
# Ensure that the policies are inclusive of all genders, sexual orientations, and family structures. Address cultural and religious considerations around reproductive health to accommodate diverse beliefs and practices. Offer the policies in multiple formats, such as digital, print, and audio, to enhance accessibility for all employees.
#
# 2. Comprehensive Benefits
# Provide fertility and family-forming benefits, including coverage for IVF, surrogacy, egg freezing, and adoption assistance. Offer support for menstrual health, menopause, and overall reproductive health leave. Access to expert advice, coaching, and digital health tools can also be included to support employees in their reproductive health journeys.
#
# 3. Manager and HR Training
# Ensure that managers and HR professionals receive training on handling reproductive health issues sensitively and effectively. This includes understanding legal rights and obligations related to reproductive health, as well as creating a supportive work environment where employees feel comfortable discussing their reproductive health needs.
#
# 4. Workplace Adjustments and Support
# Make necessary physical and environmental adjustments in the workplace to accommodate employees' reproductive health needs. This may include providing quiet spaces, workload adjustments, or other accommodations based on individual requirements. Offer mental health support through peer groups, therapy, or other resources to help employees navigate reproductive health challenges.
#
# 5. Employee Resources and Next Steps
# Provide employees with access to internal contacts for support, as well as external expert resources for additional guidance. Encourage employees to seek help and support when needed, and ensure that they are aware of the resources available to them within and outside the organization.
#
# By following these best practices, organizations can create a workplace that prioritizes reproductive and fertility health, promotes inclusivity, and supports the well-being of all employees. Implementing comprehensive and supportive policies will not only benefit individual employees but also contribute to improved workforce productivity, reduced absenteeism, and a more positive workplace culture overall.
#
# Q2: Write a 500 word report on what are the best practices for developing and applying reproductive and fertility health policies in the workplace to ensure inclusivity and support for employees?
# Answer: Developing and implementing reproductive and fertility health policies in the workplace is essential to ensure inclusivity and support for employees. These policies play a crucial role in addressing the diverse needs and challenges that employees may face regarding reproductive health. By following best practices, organizations can create a workplace environment that promotes well-being, diversity, and productivity. Here are some key best practices for developing and applying reproductive and fertility health policies in the workplace:
#
# 1. Inclusivity and Accessibility:
# Ensure that reproductive health policies are inclusive of all genders, sexual orientations, and family structures. Address cultural and religious considerations surrounding reproductive health to accommodate diverse beliefs and practices. Offer the policies in multiple formats (digital, print, audio) to enhance accessibility for all employees.
#
# 2. Comprehensive Benefits and Support:
# Provide comprehensive fertility and family-forming benefits such as IVF support, adoption assistance, and surrogacy coverage. Offer paid leave for fertility treatments, pregnancy loss, and menstrual health accommodations. Ensure access to expert advice, coaching, and digital health tools to support employees' reproductive health needs.
#
# 3. Workplace Adjustments and Support:
# Implement physical and environmental adjustments in the workplace to support employees with reproductive health conditions. Provide mental health support through peer groups, therapy, and employee resource groups. Train managers on handling reproductive health issues and ensure they are equipped to provide appropriate support to their teams.
#
# 4. Employee Resources and Next Steps:
# Create internal contacts for support regarding reproductive health issues. Provide access to external expert resources for additional guidance and support. Encourage employees to seek out the resources they need to navigate their reproductive health challenges effectively.
#
# 5. Role of Leadership:
# Engage leadership in driving change by embedding reproductive health into diversity, equity, and inclusion (DEI) and wellbeing strategies. Leaders should lead by example, creating a culture of openness, psychological safety, and support for reproductive health. Allocate budget and establish clear ROI metrics to demonstrate the impact of reproductive health policies on employee well-being and organizational outcomes.
#
# 6. Continuous Evaluation and Improvement:
# Regularly evaluate the effectiveness of reproductive health policies through employee feedback, surveys, and metrics. Continuously improve policies based on the evolving needs and feedback from employees. Stay informed about emerging best practices and industry benchmarks to ensure that the organization's reproductive health policies remain relevant and effective.
#
# By following these best practices, organizations can create a workplace environment that prioritizes reproductive and fertility health, supports employee well-being, and fosters a culture of inclusivity and support for all employees. Investing in reproductive health policies is not only beneficial for employees' physical and mental well-being but also contributes to improved productivity, retention, and overall organizational success.
#
# Q3: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Developing and implementing reproductive and fertility health policies in the workplace is crucial to ensuring inclusivity and support for all employees. By following best practices, companies can create a supportive environment that values the reproductive health needs of their diverse workforce. Here are some key practices to consider:
#
# 1. Inclusivity and Accessibility:
# Ensure that the policies are inclusive of all genders, sexual orientations, and family structures. Address cultural and religious considerations around reproductive health to accommodate diverse beliefs and practices. Offer the policies in multiple formats (digital, print, audio) to enhance accessibility for all employees.
#
# 2. Comprehensive Benefits:
# Include a range of fertility and family-forming benefits in the policies, such as IVF support, egg freezing, adoption assistance, and miscarriage leave. Flexible working policies can also help employees manage their reproductive health conditions while balancing work responsibilities.
#
# 3. Manager Training and HR Guidance:
# Provide training for managers on handling reproductive health issues sensitively and effectively. HR professionals should be well-versed in legal rights and obligations related to reproductive health in the workplace to ensure compliance and support for employees.
#
# 4. Workplace Adjustments and Support:
# Make necessary physical and environmental adjustments to accommodate employees with reproductive health conditions. This could include providing quiet spaces for rest, adjusting workloads during challenging times, and offering mental health support through peer groups or therapy sessions.
#
# 5. Employee Resources and Next Steps:
# Offer internal contacts for support and guidance on reproductive health issues. External expert resources can also be beneficial for employees seeking additional information or assistance. Encourage employees to take advantage of these resources to support their reproductive health needs.
#
# 6. Regular Evaluation and Feedback:
# Regularly evaluate the effectiveness of the reproductive and fertility health policies through employee feedback and engagement. Make adjustments as needed to ensure that the policies continue to meet the evolving needs of the workforce.
#
# By following these best practices, companies can create a workplace environment that prioritizes the reproductive health and well-being of all employees. Implementing inclusive and supportive policies can lead to improved employee retention, productivity, and overall morale within the organization. Investing in reproductive and fertility health programs demonstrates a commitment to employee well-being and can contribute to a positive company culture where all individuals feel valued and supported.
#
# Q4: Write a 500 word report on what are the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees?
# Answer: In today's modern workplace, it is crucial for companies to have comprehensive and inclusive reproductive and fertility health policies that support all employees. This not only ensures the well-being and productivity of employees but also promotes a culture of inclusivity, diversity, and support within the organization. In order to create an effective workplace reproductive and fertility health policy, there are several key components that should be included to ensure inclusivity and support for all employees.
#
# The first key component that should be included in a workplace reproductive and fertility health policy is clear and comprehensive communication. This involves clearly stating the purpose of the policy, as well as ensuring that all employees are aware of the support and resources available to them. Communication should be inclusive of all reproductive health needs, including fertility treatments, pregnancy loss, menopause, and other related concerns. Providing information in multiple formats, such as digital, print, and audio, can enhance accessibility and ensure that all employees can easily access the information they need.
#
# Another important component of a workplace reproductive and fertility health policy is the inclusion of company policies and benefits. This should include details on fertility leave, miscarriage leave, and accommodations for menstrual health. Flexible working policies should also be outlined to accommodate employees who may need time off for fertility treatments or other related issues. Additionally, the policy should detail the insurance and financial support available for treatments, consultations, and therapy, ensuring that employees have access to the resources they need to manage their reproductive and fertility health.
#
# Workplace adjustments and support are also key components that should be included in a workplace reproductive and fertility health policy. This includes providing physical and environmental adjustments, such as quiet spaces and workload adjustments, to support employees who may need accommodations for their reproductive health needs. Mental health support, such as peer groups and therapy, should also be available to employees who may be struggling with the emotional toll of fertility challenges or pregnancy loss.
#
# Manager and HR guidance is another crucial component of a workplace reproductive and fertility health policy. This involves providing training for managers on how to handle reproductive health issues sensitively and effectively. Managers should be educated on legal rights and obligations related to reproductive and fertility health, and encouraged to create a supportive and open culture within their teams.
#
# Finally, the policy should include information on employee resources and next steps. This includes providing internal contacts for support within the organization, as well as external expert resources that employees can access for additional support and guidance.
#
# In conclusion, creating an effective workplace reproductive and fertility health policy requires careful consideration of the key components that ensure inclusivity and support for all employees. By including clear communication, company policies and benefits, workplace adjustments and support, manager and HR guidance, and employee resources, organizations can create a policy that promotes a culture of inclusivity and support for all employees, regardless of their reproductive and fertility health needs.

# %%
with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)

ragas_data = []
for ref, pred in zip(qa_data, llm_results):
    ragas_data.append({
        "question": ref["question"],
        "answer": pred["answer"],
        "contexts": [pred["context_used"]],
        "ground_truth": ref["ground_truth_answer"]
    })

from datasets import Dataset
ragas_dataset = Dataset.from_list(ragas_data)

# Evaluate
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness
)
from ragas import evaluate

evaluation_scores = evaluate(
    ragas_dataset,
    metrics=[answer_relevancy, context_precision, context_recall, faithfulness],
    llm=llm
)

print(evaluation_scores)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# {'answer_relevancy': 0.9208, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 0.9336}
