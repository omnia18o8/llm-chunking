# %%
from openai import OpenAI
import voyageai as vo  
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client_vo = vo.Client(api_key=os.getenv("VOYAGE_API_KEY"))  
chat_model = "gpt-3.5-turbo"
embedding_model = "voyage-context-3"

# %%
k = 3
a = 0.6 #alpha for semantic (1.0) and keyword search (0.0)
lambda_parameter = 0.7 #lambda for diversity (1.0 is all diverse) and 0.0 is chunks are the same

# %%
import os
from ingestion import load_documents
base_path = os.path.abspath("..")
md_texts = load_documents(base_path)

# %%
from langchain_text_splitters import CharacterTextSplitter

character_text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base",    # tokenizer to count tokens
    chunk_size=1500,                # size of each chunk in tokens - good size from https://arxiv.org/pdf/2407.01219
    chunk_overlap=150,              # overlap to preserve context across chunks
)

all_chunks = []

for doc in md_texts:
    chunks = character_text_splitter.create_documents([doc["text"]])
    for c in chunks:
        c.metadata = {"source": doc["file"]}  # tag chunk with original file name (not necessary here but just in case i think)
    all_chunks.extend(chunks)
print(len(all_chunks), "total chunks created")
#print(all_chunks[0].page_content)
# Out:
# 37 total chunks created

# %%
import numpy as np

chunk_texts = [c.page_content for c in all_chunks]

resp = client_vo.contextualized_embed(
    inputs=[[text] for text in chunk_texts],
    model=embedding_model, 
    input_type="document"
)

chunk_embeddings = np.array(
    [r.embeddings[0] for r in resp.results],
    dtype=np.float32
)

chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

# %%
from rag import response_llm, embed_query
import json

with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)
questions = [q["question"] for q in qa_data]

# Run
llm_results = response_llm(
    questions=questions,
    client=client,
    chat_model=chat_model,
    chunk_embeddings=chunk_embeddings,
    chunk_texts=chunk_texts,
    embed_query=embed_query,
    k=k,
    alpha=a,
    lambda_param=lambda_parameter
)
# Out:
# Q1: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees requires a comprehensive approach that considers the diverse needs and challenges individuals may face. By following best practices, organizations can create a supportive and inclusive environment that promotes employee well-being and productivity.
#
# 1. Inclusivity and Accessibility:
# Ensure that the policies are inclusive of all genders, sexual orientations, and family structures. Address cultural and religious considerations around reproductive health to accommodate diverse beliefs and practices. Offer the policies in multiple formats (digital, print, audio) to enhance accessibility and ensure that all employees can easily access the information.
#
# 2. Policy Development:
# Create clear and comprehensive policies that cover a range of reproductive health needs, including fertility leave, miscarriage leave, and menstrual health accommodations. Implement flexible working policies that allow employees to manage their reproductive health conditions effectively while balancing work responsibilities. Provide insurance and financial support for fertility treatments to ease the financial burden on employees seeking reproductive assistance.
#
# 3. Workplace Adjustments:
# Make necessary physical and environmental adjustments in the workplace to accommodate employees with reproductive health conditions. This may include providing quiet spaces for rest or privacy, adjusting workloads to accommodate medical appointments, and creating a supportive and understanding work environment. Ensure that mental health support is available, such as peer support groups or access to therapy, to help employees cope with the emotional aspects of reproductive health challenges.
#
# 4. Manager and HR Guidance:
# Offer training for managers on how to handle reproductive health issues sensitively and effectively. Ensure that managers are aware of employees' legal rights and obligations regarding reproductive health accommodations and support. Encourage open communication between employees and managers to facilitate understanding and support.
#
# 5. Employee Resources and Next Steps:
# Provide internal contacts for employees to reach out to for support and guidance regarding reproductive health issues. Offer access to external expert resources, such as medical professionals or counselors, to provide additional support and information. Encourage employees to seek help when needed and promote a culture of openness and support within the organization.
#
# By following these best practices for developing and implementing reproductive and fertility health policies in the workplace, organizations can create a supportive and inclusive environment that prioritizes the well-being of all employees. This approach not only enhances employee satisfaction and retention but also contributes to a positive workplace culture where all individuals feel valued and supported.
#
# Q2: Write a 500 word report on what are the best practices for developing and applying reproductive and fertility health policies in the workplace to ensure inclusivity and support for employees?
# Answer: Developing and applying reproductive and fertility health policies in the workplace requires careful consideration of inclusivity and support for all employees. By following best practices, organizations can create a positive and supportive environment that addresses the diverse needs of their workforce. Here are some key guidelines for implementing effective reproductive and fertility health policies:
#
# 1. Conduct Comprehensive Research: Before drafting any policies, it's essential to conduct thorough research on the cultural, religious, and legal considerations surrounding reproductive health. Understanding the unique challenges and preferences of different demographic groups within the workforce will help tailor policies to meet their specific needs.
#
# 2. Ensure Inclusivity: Reproductive and fertility health policies should be inclusive of all genders, sexual orientations, and family structures. Consider offering a range of benefits such as fertility treatments, menstrual and menopause leave, adoption assistance, and surrogacy support to accommodate diverse needs within the organization.
#
# 3. Provide Multiple Support Channels: Employees may have varying levels of comfort discussing reproductive health issues openly. It is crucial to provide multiple support channels, including confidential counseling services, employee resource groups, and access to external experts, to ensure that employees feel supported and empowered to seek help when needed.
#
# 4. Training and Awareness Programs: Implement training programs for managers and HR staff to raise awareness about reproductive health issues and provide guidance on how to support employees effectively. Encouraging open dialogue and creating a culture of transparency around reproductive health can help reduce stigma and promote well-being in the workplace.
#
# 5. Flexible Policies: Flexible working arrangements, unpaid leave options, and accommodations for employees with chronic reproductive health conditions can help create a supportive and inclusive work environment. By allowing for flexibility in work schedules and providing reasonable accommodations, organizations can better meet the needs of their employees.
#
# 6. Regular Evaluation and Feedback: Continuous evaluation of reproductive and fertility health policies is vital to ensure their effectiveness and relevance. Encourage feedback from employees through surveys, focus groups, and one-on-one discussions to identify areas for improvement and make necessary adjustments to the policies.
#
# 7. Legal Compliance: Stay informed about relevant laws and regulations related to reproductive and fertility health in the workplace. Ensure that policies are compliant with legal requirements and respect employees' rights to privacy and confidentiality regarding their reproductive health issues.
#
# By following these best practices, organizations can create a workplace that prioritizes reproductive and fertility health, supports employees' well-being, and promotes inclusivity and diversity. Ultimately, investing in reproductive health policies can lead to a more engaged, productive, and satisfied workforce.
#
# Q3: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Developing and implementing reproductive and fertility health policies in the workplace is crucial to ensure inclusivity and support for all employees. By following best practices, organizations can create a supportive environment that addresses the diverse reproductive health needs of their workforce. Here are some key practices to consider:
#
# 1. Inclusivity and Accessibility:
# Ensure that the reproductive and fertility health policies are inclusive of all genders, sexual orientations, and family structures. Address cultural and religious considerations around reproductive health to accommodate diverse beliefs and practices. Offer the policies in multiple formats (digital, print, audio) to enhance accessibility for all employees.
#
# 2. Company Policies and Benefits:
# Include provisions for fertility leave, miscarriage leave, and menstrual health accommodations in the workplace policies. Implement flexible working policies to support employees managing reproductive health conditions or undergoing fertility treatments. Provide insurance coverage and financial support for treatments to alleviate the financial burden on employees.
#
# 3. Workplace Adjustments and Support:
# Make necessary physical and environmental adjustments in the workplace to accommodate the needs of employees with reproductive health conditions. This could include providing quiet spaces, adjusting workloads, or implementing ergonomic solutions. Offer mental health support through peer groups, therapy sessions, or employee assistance programs to help individuals cope with the emotional aspects of reproductive health challenges.
#
# 4. Manager and HR Guidance:
# Conduct training sessions for managers on how to handle reproductive health issues sensitively and effectively. Educate them on legal rights and obligations related to reproductive health accommodations and support. Empower HR professionals to provide guidance and resources to employees seeking assistance for reproductive health concerns.
#
# 5. Employee Resources and Next Steps:
# Create internal resources such as employee support groups or designated contacts for individuals seeking guidance on reproductive health matters. Offer access to external expert resources for specialized support and guidance. Encourage employees to take advantage of these resources and take proactive steps towards managing their reproductive health effectively.
#
# By implementing these best practices, organizations can create a workplace culture that prioritizes reproductive and fertility health inclusivity and support. This not only enhances employee well-being and satisfaction but also contributes to a more diverse, inclusive, and supportive work environment for all employees.
#
# Q4: Write a 500 word report on what are the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees?
# Answer: An effective workplace reproductive and fertility health policy plays a crucial role in ensuring inclusivity and support for all employees. By addressing the unique needs and challenges that individuals may face in relation to reproductive health, such a policy can create a more inclusive and supportive work environment. In this report, we will outline the key components that should be included in a workplace reproductive and fertility health policy to achieve these goals.
#
# 1. Introduction & Purpose:
# The policy should clearly state the purpose of the guide, emphasizing the importance of supporting employees in their reproductive health journey. It should also ensure inclusivity by acknowledging and respecting all reproductive health needs, regardless of gender, sexual orientation, or family structure.
#
# 2. Company Policies & Benefits:
# The policy should outline specific company policies and benefits related to reproductive health. This includes provisions for fertility leave, miscarriage leave, and accommodations for menstrual health issues. Additionally, flexible working policies should be detailed to allow employees to attend appointments or seek treatment without fear of repercussions. Information on insurance coverage and financial support for fertility treatments should also be included.
#
# 3. Workplace Adjustments & Support:
# Physical and environmental adjustments should be considered to support employees experiencing reproductive health challenges. This may include providing quiet spaces for rest or privacy, adjusting workloads to accommodate medical appointments, or offering ergonomic support for comfort. Mental health support should also be available, such as peer support groups or access to therapy services.
#
# 4. Manager & HR Guidance:
# Training for managers on handling reproductive health issues is essential for creating a supportive workplace culture. Managers should be equipped with the knowledge and skills to respond sensitively to employees' needs and provide appropriate support. Information on legal rights and obligations regarding reproductive health should also be provided to ensure compliance with relevant laws and regulations.
#
# 5. Employee Resources & Next Steps:
# The policy should include information on internal contacts for support, such as HR representatives or designated employee assistance programs. External expert resources, such as fertility clinics or reproductive health organizations, should also be accessible to employees. Clear guidance on the next steps to take if an employee needs support or information should be provided to ensure prompt and appropriate assistance.
#
# In conclusion, creating a workplace reproductive and fertility health policy that is inclusive and supportive of all employees requires careful consideration of the unique needs and challenges that individuals may face. By including key components such as clear communication, company policies and benefits, workplace adjustments and support, manager and HR guidance, and employee resources, organizations can create a more supportive and inclusive work environment for all employees. By prioritizing reproductive health and fertility needs, organizations can demonstrate their commitment to promoting diversity, inclusion, and employee well-being.

# %%
with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)

ragas_data = []
for ref, pred in zip(qa_data, llm_results):
    ragas_data.append({
        "question": ref["question"],
        "answer": pred["answer"],
        "contexts": [pred["context_used"]],
        "ground_truth": ref["ground_truth_answer"]
    })

from datasets import Dataset
ragas_dataset = Dataset.from_list(ragas_data)

# Evaluate
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness
)
from ragas import evaluate

evaluation_scores = evaluate(
    ragas_dataset,
    metrics=[answer_relevancy, context_precision, context_recall, faithfulness],
    llm=llm
)

print(evaluation_scores)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# {'answer_relevancy': 0.9158, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 0.9728}
