# %%
from openai import OpenAI
import voyageai as vo  
import os
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client_vo = vo.Client(api_key=os.getenv("VOYAGE_API_KEY"))  
chat_evaluator_model = "gpt-5-nano"
chat_judge_model = "gpt-4.1-mini"
embedding_model = "voyage-context-3"

# %%
k = 3
a = 0.6 #alpha for semantic (1.0) and keyword search (0.0)
lambda_parameter = 0.7 #lambda for diversity (1.0 is all diverse) and 0.0 is chunks are the same

# %%
import os
from ingestion import load_documents
base_path = os.path.abspath("..")
md_texts = load_documents(base_path)

# %%
from langchain_text_splitters import CharacterTextSplitter

character_text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base",    # tokenizer to count tokens
    chunk_size=1500,                # size of each chunk in tokens - good size from https://arxiv.org/pdf/2407.01219
    chunk_overlap=150,              # overlap to preserve context across chunks
)

all_chunks = []

for doc in md_texts:
    chunks = character_text_splitter.create_documents([doc["text"]])
    for c in chunks:
        c.metadata = {"source": doc["file"]}  # tag chunk with original file name (not necessary here but just in case i think)
    all_chunks.extend(chunks)
print(len(all_chunks), "total chunks created")
#print(all_chunks[0].page_content)
# Out:
# 37 total chunks created

# %%
# import numpy as np

# chunk_texts = [c.page_content for c in all_chunks]

# resp = client_vo.contextualized_embed(
#     inputs=[[text] for text in chunk_texts],  # list of lists
#     model=embedding_model,
#     input_type="document",
# )
# chunk_embeddings = np.array([r.embeddings[0] for r in resp.results], dtype=np.float32)
# chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

import numpy as np

chunk_texts = [c.page_content for c in all_chunks]

resp = client_vo.embed(
    chunk_texts,  # list of lists
    model=embedding_model,
    input_type="document",
)
chunk_embeddings = np.array(
    resp.embeddings,
    dtype=np.float32
)
chunk_embeddings = chunk_embeddings / np.linalg.norm(chunk_embeddings, axis=1, keepdims=True)

# %%
from rag import response_llm, embed_query
import json

with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)
questions = [q["question"] for q in qa_data]

llm_results = response_llm(
    questions=questions,
    client=client,
    chat_model=chat_evaluator_model,
    chunk_embeddings=chunk_embeddings,
    chunk_texts=chunk_texts,
    embed_query=embed_query,
    k=k,
    alpha=a,
    lambda_param=lambda_parameter
)
# Out:
# Q1: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Best practices for developing and implementing reproductive and fertility health policies in the workplace
#
# Purpose and alignment
# - Start with a customized guide that reflects your organization’s culture and workforce demographics. Align policy development with business strategy and employee needs to support inclusion, well-being, and productivity.
# - Embed reproductive health into DEI and wellbeing strategies, with leadership modeling openness and psychological safety. Allocate budget and define clear ROI metrics to demonstrate impact.
#
# Data-driven, iterative development
# - Begin with preparatory work: review existing data (surveys, exit interviews, focus groups) to understand awareness and gaps. Example: 25% of employees may be aware of fertility benefits, highlighting communication needs.
# - Use the 5Ps Framework to identify gaps (People, Policies, Programs, Practices, Partners) and engage stakeholders across HR, legal, and communications.
# - Treat policy development as an iterative process: reassess current practices against the new framework, and refine accordingly. Involvement of employees increases uptake and reduces mismanagement risk (uptake gains up to 30% when employees help develop policies).
#
# Core policy components
# - Flexible work and leave policies: provide time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related needs; consider flexible working arrangements for medical appointments or symptom management.
# - Health benefits and insurance: detail available coverage for fertility treatments, consultations, therapy, and related costs; consider financial support options.
# - Reasonable accommodations: specify workplace adjustments such as ergonomic support, private lactation rooms, or remote work options.
# - Family-forming benefits: include IVF, surrogacy, egg freezing where appropriate; ensure policies cover diverse family structures and gender identities.
# - Menstrual, menopause, and reproductive health leave: ensure explicit leave options and supportive workplace adjustments for these conditions.
# - Access to expert support: provide coaching, peer groups, and digital tools to assist employees navigating fertility, pregnancy loss, menopause, and broader reproductive health.
#
# Inclusivity and accessibility
# - Ensure policies are inclusive of all genders, sexual orientations, and family structures. Address cultural and religious considerations and offer materials in multiple formats (digital, print, audio) to maximize accessibility.
# - Create quiet spaces and adjust workloads to accommodate treatment and recovery periods. Establish mental health and peer support groups and an ERG to share experiences and guidance.
# - Normalize discussions through awareness initiatives (e.g., webinars) and external expert partnerships to reduce stigma and encourage disclosure where appropriate.
#
# Manager and HR guidance
# - Provide training for managers on sensitive conversations, legal obligations, and employee rights. Emphasize confidentiality and psychological safety in reproductive health discussions.
# - Support leaders in implementing policies, including how to handle disclosures and make reasonable accommodations without bias or stigma.
#
# Implementation and measurement
# - Roll out concrete policy updates (e.g., paid fertility leave, miscarriage leave, flexible work during menstrual health challenges) and monitor uptake and impact.
# - Allocate budget for benefits and programs; define ROI metrics (e.g., improved retention, reduced absenteeism, better engagement) and track progress over time.
# - Leverage external and internal support resources: We Are Eden offers an online course, policy audits, workshops, peer support groups, lived-experience repositories, and expert-led webinars to guide implementation and ongoing support.
#
# Global and cultural considerations
# - Adapt policies to regional attitudes toward reproductive health, ensuring cultural sensitivity and religious inclusivity. Provide education, access, and affordability through partnerships with healthcare providers and NGOs where needed.
# - Ensure compliance with local labor laws and healthcare regulations, while maintaining a consistent core approach to inclusivity and support across regions.
#
# Next steps
# - Enroll in We Are Eden’s online course, book a custom consultation, and engage employees with expert-led support to drive real culture change. Consider case examples from Unilever, Google, NatWest, and others as benchmarks for shaping your own program.
#
# Q2: Write a 500 word report on what are the best practices for developing and applying reproductive and fertility health policies in the workplace to ensure inclusivity and support for employees?
# Answer: Best practices for developing and applying reproductive and fertility health policies in the workplace
#
# - Establish a clear purpose and strategic alignment
#   - Define the guide’s purpose: to support employees dealing with reproductive and fertility health challenges.
#   - Align policies with company values on well-being and inclusion, while reducing mismanagement and litigation risk.
#   - Ensure policies reflect business strategy and employee needs, and reflect the organization’s culture and workforce demographics.
#
# - Build a structured, data-informed policy
#   - Use a clear structure so the guide is easy to navigate for employees, managers, and HR.
#   - Conduct preparatory work: review existing data (surveys, exit interviews, focus groups) to surface awareness gaps and needs.
#   - Identify gaps with a systematic framework (the 5Ps) and engage stakeholders across HR, legal, and communications.
#   - Draft policy elements with concrete, actionable sections: fertility treatment support, flexible work during menopause, dedicated health leave, and other reasonable accommodations.
#   - Communicate the guide internally using clear, accessible language and multiple formats (digital, print, audio) to maximize reach.
#
# - Define comprehensive, inclusive policy components
#   - Flexible work and leave: cover fertility treatments, pregnancy loss, menopause, and other reproductive health needs.
#   - Health benefits and insurance: detail coverage for fertility treatments, consultations, therapy, and financial support.
#   - Reasonable accommodations: ergonomic adjustments, private lactation rooms, remote work options, and workload adjustments.
#   - Fertility and family-forming benefits: IVF, surrogacy, egg freezing, adoption, and related support.
#   - Menstrual and menopause support: leave and workplace adjustments as part of broader reproductive health care.
#   - Access to expert support: coaching, peer groups, and digital tools to assist employees navigating reproductive health challenges.
#   - Leadership role: embed reproductive health into DEI and wellbeing strategies; promote psychological safety; allocate budget and define ROI.
#
# - Prioritize inclusivity, accessibility, and cultural awareness
#   - Ensure policies cover all genders, sexual orientations, and family structures.
#   - Address cultural and religious considerations; adapt benefits to regional contexts as needed.
#   - Provide multiple formats and accessible design; offer quiet spaces, adjusted workloads during treatment periods, and mental health/peer support groups.
#   - Use Employee Resource Groups and external experts to normalize discussions and reduce stigma.
#
# - Implement with practical steps and strong governance
#   - Update policies with concrete actions (e.g., paid fertility leave, miscarriage leave, flexible working for menstrual health challenges).
#   - Create confidential HR support channels and train managers to handle sensitive conversations with confidentiality and psychological safety.
#   - Provide manager and HR training on legal obligations, employee rights, and responding to reproductive health needs.
#   - Launch awareness and support initiatives: webinars, external fertility specialists, ERGs, and lived-experience resources.
#
# - Measure, refine, and scale
#   - Treat policy development as iterative; revisit and refine using ongoing self-assessment and feedback.
#   - Track impact: uptake of benefits, retention and engagement metrics, productivity, absenteeism, and ROI.
#   - Use case studies to inform practice: examples from Unilever, Google, Co-op, PwC, NatWest illustrate benefits such as improved retention, reduced stigma, and higher engagement.
#   - Leverage partner resources (e.g., We Are Eden) for courses, audits, implementations, and ongoing employee support.
#
# - Operationalize through targeted next steps
#   - Conduct policy audits and benchmarking; tailor strategy to company culture and regional laws.
#   - Develop an implementation roadmap with pilot programs, then scale successful initiatives.
#   - Provide ongoing employee education, peer support networks, and expert-led sessions to sustain culture change.
#
# These practices, drawn from the framework for creating an effective reproductive and fertility health guide, support inclusive, legally compliant, and practically usable policies that help employees navigate reproductive health challenges while enhancing organizational well-being and productivity.
#
# Q3: Write a 500 word report on what are the best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees?
# Answer: Best practices for developing and implementing reproductive and fertility health policies in the workplace to ensure inclusivity and support for all employees
#
# Executive summary
# A well-structured, data-informed policy that is inclusive of all genders, family structures, and cultural contexts can improve accessibility, reduce stigma, boost engagement, and support business goals such as productivity and retention. The guidance below draws from established components, implementation steps, and real-world case examples.
#
# Foundational approach
# - Structure and clarity: Build a guide that is clear, accessible, and actionable. It should be easy to navigate for employees, managers, and HR, with policies and support mechanisms clearly outlined.
# - Data-driven preparation: Begin with a preparatory phase that reviews existing data (surveys, exit interviews, focus groups) to identify awareness gaps and needs. Use the 5Ps Framework to identify gaps and shape policy elements.
# - Stakeholder engagement: Involve HR, legal, and communications early, with cross-functional input throughout drafting and rollout.
# - Employee involvement: Actively involve employees in policy development; research suggests involvement can increase benefit uptake by up to 30%.
#
# Core policy content and design
# - Core policy areas: Include flexible work and leave policies for fertility treatments, pregnancy loss, menopause, and other reproductive health concerns; comprehensive health benefits and insurance coverage; and reasonable accommodations (ergonomics, private lactation spaces, remote work as appropriate).
# - Fertility and family-forming benefits: Consider IVF, surrogacy, egg freezing, adoption support as part of benefits where relevant to the workforce.
# - Leave and flexibility: Provide menstrual, menopause, and reproductive health leave; accommodate medical treatments and symptom management through flexible scheduling.
# - Expert support: Provide access to coaching, peer groups, and digital tools to support employees navigating reproductive health challenges.
# - Leadership and ROI: Embed reproductive health into DEI and wellbeing strategies, set the tone for psychological safety, allocate budget, and define ROI metrics to track impact.
#
# Implementation and operational steps
# - Policy updates and examples: Implement tangible changes such as paid fertility leave, miscarriage leave, and flexible working arrangements during menstrual health challenges.
# - Communication and language: Communicate policies using clear, accessible language; tailor messaging to reflect diverse workforce needs.
# - Training and guidance: Provide manager and HR training on sensitive conversations, legal obligations, and how to respond to reproductive health needs; address workplace culture and stigma; maintain confidentiality and psychological safety.
# - Awareness and support infrastructure: Launch regular well-being sessions (webinars on fertility, menopause, etc.); partner with external reproductive health specialists for consultations; establish Employee Resource Groups and support networks.
# - Accessibility and formats: Offer the guide in multiple formats (digital, print, audio) to maximize accessibility; ensure quiet spaces and workload adjustments are available during treatment periods.
#
# Inclusivity and cultural considerations
# - Inclusivity across identities: Ensure the guide covers all genders, sexual orientations, and family structures.
# - Cultural and religious sensitivity: Adapt policies to regional attitudes toward reproductive health; provide religiously inclusive options and support.
# - Global applicability: Use education, awareness campaigns, and accessible access to care (partnering with providers and NGOs) to broaden reach in resource-limited areas; ensure compliance with local laws.
#
# Evidence and case examples
# - Case studies illustrate tangible benefits: Unilever’s menopause and fertility support improved retention; Google’s family-forming benefits enhanced DEI and satisfaction; NatWest and PwC demonstrate reduced stigma and better return-to-work outcomes. These examples highlight the value of leadership commitment, comprehensive benefits, and supportive ecosystems.
#
# Resources and next steps
# - Enroll in We Are Eden’s online course to structure and implement a workplace reproductive health strategy, access policy audits, and engage expert-led support networks.
# - Utilize consulting, training, and peer support services to tailor the policy to your workforce and regional legal context.
#
# In summary, best practices center on a structured, data-driven, and inclusive design; clear and flexible policy content; strong leadership and funding; proactive communication and training; and accessible support systems that reflect diverse experiences and cultures.
#
# Q4: Write a 500 word report on what are the key components that should be included in a workplace reproductive and fertility health policy to ensure inclusivity and support for all employees?
# Answer: A comprehensive workplace reproductive and fertility health policy should be designed to be inclusive, practical, and easy to navigate for every employee. Drawing on the guidance in Module 2, the following key components are essential to ensure broad support and compliance.
#
# 1) Core policies to support employees
# - Flexible work and leave policies: Include time off for fertility treatments, pregnancy loss, menopause, and other reproductive health-related needs.
# - Health benefits and insurance: Detail what is covered for fertility treatments, consultations, therapy, and related services, plus any financial support.
# - Reasonable accommodations: Outline workplace adjustments such as ergonomic supports, private lactation rooms, and remote work options to reduce barriers during reproductive health challenges.
#
# 2) Clear structure and accessible processes
# - Simple, clear language: Use accessible, inclusive terms and avoid medical jargon.
# - Step-by-step guidance: Provide explicit processes for applying for leave, accessing HR support, and confidentiality protocols.
# - Contact points: List who to contact within HR, employee assistance programs, and external resources for further help.
#
# 3) Inclusivity, accessibility, and cultural sensitivity
# - Inclusive scope: Ensure policies cover all genders, sexual orientations, and family structures.
# - Cultural and religious considerations: Address diverse beliefs and practices related to reproductive health.
# - Multiple formats: Offer the guide in digital, print, and audio formats to maximize accessibility.
#
# 4) Cultivating a supportive workplace culture
# - Education to reduce bias: Provide training and resources to address reproductive health-related biases and their impact.
# - Manager and HR guidance: Equip managers and HR teams with strategies to foster an open, supportive environment.
# - Confidentiality and psychological safety: Emphasize protecting privacy and creating safe spaces for discussions.
#
# 5) Governance, implementation, and resources
# - Manager and HR training: Include training on handling reproductive health issues and understanding legal rights and obligations.
# - Employee resources and next steps: Supply internal contacts for support as well as external expert resources.
# - Workplace adjustments and mental health support: Beyond physical accommodations, offer access to mental health resources and peer support where available.
# - Regional and legal alignment: Customize policies to local labor laws and healthcare infrastructure, as demonstrated by regional case examples, and partner with healthcare providers or NGOs to broaden access.
#
# 6) Communication, awareness, and ongoing improvement
# - Clear communication and ongoing education: Regularly inform employees about available policies and benefits; integrate awareness campaigns to normalize conversations.
# - Stakeholder engagement: Involve employees in policy design to ensure relevance and uptake, reinforcing the message that the policy evolves with needs.
# - Measure and adapt: Use feedback and evolving best practices to refine policy offerings over time.
#
# A practical framework for implementation mirrors the elements highlighted in the module’s guidance:
# - Introduction and purpose to state intent and inclusivity.
# - Company policies and benefits, including leave types, flexible work, and insurance/financial support.
# - Workplace adjustments and support, both physical and mental health resources.
# - Manager and HR guidance to ensure competent, rights-based support.
# - Employee resources and next steps with clear internal and external contacts.
#
# In sum, an inclusive policy should provide concrete benefits and accommodations, clear procedures, accessible and respectful language, cultural sensitivity, proactive stigma reduction, and ongoing opportunities for feedback and improvement. This approach aligns with the core lessons: essential policies, clear structure, inclusivity, and a culture that supports open, confidential conversations.

# %%
with open("qa_long_dataset.json", "r") as f:
    qa_data = json.load(f)

ragas_data = []
for ref, pred in zip(qa_data, llm_results):
    ragas_data.append({
        "question": ref["question"],
        "answer": pred["answer"],
        "contexts": [pred["context_used"]],
        "ground_truth": ref["ground_truth_answer"]
    })

from datasets import Dataset
ragas_dataset = Dataset.from_list(ragas_data)

# Evaluate
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name=chat_judge_model, temperature=0)

from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness
)
from ragas import evaluate

evaluation_scores = evaluate(
    ragas_dataset,
    metrics=[answer_relevancy, context_precision, context_recall, faithfulness],
    llm=llm
)

print(evaluation_scores)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# LLM returned 1 generations instead of requested 3. Proceeding with 1 generations.
# {'answer_relevancy': 0.9270, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 1.0000}
